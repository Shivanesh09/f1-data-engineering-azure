# %%
formula1dlproject1_SAS_key = dbutils.secrets.get(scope = 'formula1-scope', key = 'formula1dlproject1-SAS-key')

# %%
spark.conf.set("fs.azure.account.auth.type.formula1dlproject1.dfs.core.windows.net", "SAS")
spark.conf.set("fs.azure.sas.token.provider.type.formula1dlproject1.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set("fs.azure.sas.fixed.token.formula1dlproject1.dfs.core.windows.net", formula1dlproject1_SAS_key)
